# %% [markdown]
# <a href="https://colab.research.google.com/github/jon-medina04/Practicas_Python/blob/main/D%C3%ADa_2_CLASE_2_Pandas_FOR_IF_Dic_sin_sol_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# Ejercicio 1: Crea un DataFrame con las variables Nombre, Edad y Ciudad.

# %%
datos = {
    'Nombre': ['Ana', 'Luis', 'Marta', 'Jose'],
    'Edad': [23, 34, 22, 40],
    'Ciudad': ['Madrid', 'Barcelona', 'Valencia', 'Sevilla']
}

df = pd.DataFrame(datos)

df
# Out:
#   Nombre  Edad     Ciudad
# 0    Ana    23     Madrid
# 1   Luis    34  Barcelona
# 2  Marta    22   Valencia
# 3   Jose    40    Sevilla

# %% [markdown]
# Imprime las edades:

# %%
df.Edad
# Out:
# 0    23
# 1    34
# 2    22
# 3    40
# Name: Edad, dtype: int64

# %% [markdown]
# Ejercicio 2: Elimina la columna "Ciudad" del DataFrame.

# %%
df.drop(columns='Ciudad', inplace=True)
df
# Out:
#   Nombre  Edad
# 0    Ana    23
# 1   Luis    34
# 2  Marta    22
# 3   Jose    40

# %% [markdown]
# Ejercicio 3: Elimina la fila correspondiente a "Marta" del DataFrame.

# %%
df.drop(index=2, inplace=True)
df
# Out:
#   Nombre  Edad
# 0    Ana    23
# 1   Luis    34
# 3   Jose    40

# %% [markdown]
# Ejercicio 4: Filtra el DataFrame para mostrar solo las filas donde la edad es mayor de 25 años.

# %%
df[df.Edad > 25]
# Out:
#   Nombre  Edad
# 1   Luis    34
# 3   Jose    40

# %% [markdown]
# Ejercicio 5: Filtra el DataFrame para mostrar solo las filas donde el nombre empieza con la letra "L".

# %%
df[df.Nombre.str.startswith('L')]
# Out:
#   Nombre  Edad
# 1   Luis    34

# %% [markdown]
# Ejercicio 6: Cambia el nombre de la columna "Nombre" a "Nombre Completo".

# %%
df.rename(columns={'Nombre': 'Nombre Completo'}, inplace=True)
df
# Out:
#   Nombre Completo  Edad
# 0             Ana    23
# 1            Luis    34
# 3            Jose    40

# %% [markdown]
# Ejercicio 7: Agrega una nueva columna llamada "Salario" con los valores [3000, 4000, 3500, 4500].

# %%
df['Salario'] = [3000, 4000, 3500]
df
# Out:
#   Nombre Completo  Edad  Salario
# 0             Ana    23     3000
# 1            Luis    34     4000
# 3            Jose    40     3500

# %% [markdown]
# Ejercicio 8: Muestra un resumen estadístico del DataFrame.

# %%
df.describe(
    include='all'
)
# Out:
#        Nombre Completo       Edad  Salario
# count                3   3.000000      3.0
# unique               3        NaN      NaN
# top                Ana        NaN      NaN
# freq                 1        NaN      NaN
# mean               NaN  32.333333   3500.0
# std                NaN   8.621678    500.0
# min                NaN  23.000000   3000.0
# 25%                NaN  28.500000   3250.0
# 50%                NaN  34.000000   3500.0
# 75%                NaN  37.000000   3750.0
# max                NaN  40.000000   4000.0

# %% [markdown]
# Ejercicio 9: Escribe un bucle for que imprima cada elemento de la siguiente lista.

# %%
numeros = [1, 9999, 3, 4, 5]

# %% [markdown]
# Ejercicio 10: Escribe un bucle for que imprima cada elemento de la lista anterior junto con su índice.

# %%
for i, numero in enumerate(numeros):
    print(i, numero)
# Out:
# 0 1
# 1 9999
# 2 3
# 3 4
# 4 5

# %% [markdown]
# Ejercicio 11: Escribe un bucle for que calcule la suma de todos los elementos de la lista numeros.

# %%
suma = 0
for i in numeros:
    suma = suma + i

print(f"La suma total es {suma}")
# Out:
# La suma total es 10012

# %% [markdown]
# Ejercicio 12: Escribe un bucle for que imprima solo los números pares de la lista numeros.

# %%
for i in numeros:
    if i % 2 == 0:
        print(i)
# Out:
# 4

# %% [markdown]
# Ejercicios 13: Escribe un bucle for que cree una nueva lista con el cuadrado de cada número en la lista numeros.

# %%
for i in numeros:
    print(i**2)
# Out:
# 1
# 99980001
# 9
# 16
# 25

# %% [markdown]
# Ejercicio 14:  Escribe un bucle for que itere sobre dos listas y las combine en una lista de tuplas:

# %%
for i in zip(nombres, edades):
    print(i)
# Out:
# ('Ana', 23)
# ('Luis', 34)
# ('Marta', 22)
# ('Jose', 40)

# %% [markdown]
# Ejercicio 15: Escribe un bucle for que encuentre y muestre los elementos comunes entre las dos siguientes list.

# %%
for i in nombres:
    if i in edades:
        print(i)

# %% [markdown]
# Ejercicio 16: Escribe un bucle for que genere un diccionario donde las claves sean los elementos de la lista nombres y los valores sean los elementos de la lista edades.

# %%
for i in zip(nombres, edades):
    print(i)
# Out:
# ('Ana', 23)
# ('Luis', 34)
# ('Marta', 22)
# ('Jose', 40)

# %% [markdown]
# Ejercicio 17:  Escribe un bucle for que cuente la frecuencia de cada elemento en la siguiente lista:

# %%
for i in nombres:
    print(i, nombres.count(i))
# Out:
# Ana 1
# Luis 1
# Marta 1
# Jose 1
